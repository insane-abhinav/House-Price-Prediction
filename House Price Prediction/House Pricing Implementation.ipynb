# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Housing.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
df.info()

# %%
df.isnull().sum()

# %%
oceanProximity = pd.get_dummies(df['ocean_proximity'],drop_first=True)

# %%
oceanProximity
# Out:
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 0           0       0         1           0
# 1           0       0         1           0
# 2           0       0         1           0
# 3           0       0         1           0
# 4           0       0         1           0
# ...       ...     ...       ...         ...
# 20635       1       0         0           0
# 20636       1       0         0           0
# 20637       1       0         0           0
# 20638       1       0         0           0
# 20639       1       0         0           0
#
# [20640 rows x 4 columns]

# %%
df = df.drop('ocean_proximity',axis=1)

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
df = pd.concat([df,oceanProximity],axis=1)

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# ## Handling Missing Value

# %%
bmean = df['total_bedrooms'].mean()

# %%
df['total_bedrooms'].fillna(value=bmean,inplace = True)

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# INLAND                0
# ISLAND                0
# NEAR BAY              0
# NEAR OCEAN            0
# dtype: int64

# %% [markdown]
# ## Dependent and Independent feature Splitting

# %%
y=df['median_house_value'].values

# %%
X = df.drop(labels='median_house_value',axis=1).values

# %%
X
# Out:
# array([[-122.23,   37.88,   41.  , ...,    0.  ,    1.  ,    0.  ],
#        [-122.22,   37.86,   21.  , ...,    0.  ,    1.  ,    0.  ],
#        [-122.24,   37.85,   52.  , ...,    0.  ,    1.  ,    0.  ],
#        ...,
#        [-121.22,   39.43,   17.  , ...,    0.  ,    0.  ,    0.  ],
#        [-121.32,   39.43,   18.  , ...,    0.  ,    0.  ,    0.  ],
#        [-121.24,   39.37,   16.  , ...,    0.  ,    0.  ,    0.  ]])

# %% [markdown]
# ## Train Test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
reg= LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred = reg.predict(X_test)

# %% [markdown]
# ## R2 Score

# %%
reg.score(X_test,y_test)
# Out:
# 0.6257351821159716

# %% [markdown]
# ## RMSE

# %%
from sklearn.metrics import mean_squared_error
import math
mse=mean_squared_error(y_test,pred)
rmse=math.sqrt(mse)
rmse
# Out:
# 70031.41991955655

# %% [markdown]
# ## Mean Squared Error

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,pred)
# Out:
# 4904399775.949262
